# %% [markdown]
# # Welcome to My First Notebook☄️,where we will delve into the captivating world of anime💙
# ![hmmm.jpg](attachment:hmmm.jpg)

# %% [markdown]
#  # Steps for Data Analysis Process
#  ----------------------
#  ### [1-Define the Problem or Research Question](#DefinetheProblemorResearchQuestion:)
#  ### [2-Collect Data](#CollectData)
#  ### [3-Data Preprocessing](#DataPreprocessing)
#  ### [4-Analyzing the Data](#AnalyzingtheData)
#  ### [5-Data Visualization ](#DataVisualization)

# %% [markdown]
# <a id='DefinetheProblemorResearchQuestion:'></a>

# %% [markdown]
# # 1-Define the Problem or Research Question:
# ----------------------------
# **The purpose of this notebook is to perform exploratory data analysis (EDA) on the Top Anime Dataset 2024. The dataset provides a comprehensive overview of the top animes of 2024, including various attributes such as scores, popularity, genres, and more.**
#
# ## Objectives:
# 1. **Understand the distribution and trends of anime scores**
# 2. **Analyze the popularity of animes**
# 3. **Explore relationships between different features**
# 4. **Identify key genres and studios**
# 5. **Examine other relevant features**
#
# ## Research Questions:
# 1. **What is the general distribution of scores among the top animes in the dataset?**
# 2. **How is the popularity of animes distributed, and what are the most popular titles?**
# 3. **What are the top 10 animes with the highest average ratings?**
# 4. **Which genres are most prevalent in the dataset, and which studios produce the most animes?**
# 5. **How does the number of episodes affect the average rating of an anime?**

# %% [markdown]
# <a id='CollectData'></a>

# %% [markdown]
# # 2-Collect Data & Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Top_Anime_data')

# %% [markdown]
# <a id='DataPreprocessing'></a>

# %% [markdown]
# # 3-Data Preprocessing

# %% [markdown]
# **1. Display the first few rows to get an initial sense of the data.**

# %%
data.head()
# Out:
#    Score  Popularity  Rank  Members  \
# 0   9.38         284     1      710
# 1   9.09           3     2        3
# 2   9.07          13     3        2
# 3   9.06         342     4      630
# 4   9.05          21     5        2
#
#                                          Description  \
# 0  During their decade-long quest to defeat the D...
# 1  After a horrific alchemy experiment goes wrong...
# 2  Eccentric scientist Rintarou Okabe has a never...
# 3  Gintoki, Shinpachi, and Kagura return as the f...
# 4  Seeking to restore humanity's diminishing hope...
#
#                                             Synonyms  \
# 0                             Frieren at the Funeral
# 1  Hagane no Renkinjutsushi: Fullmetal Alchemist,...
# 2                                                NaN
# 3                                    Gintama' (2015)
# 4                                                NaN
#
#                      Japanese                           English Type Episodes  \
# ...

# %%
data.columns
# Out:
# Index(['Score', 'Popularity', 'Rank', 'Members', 'Description', 'Synonyms',
#        'Japanese', 'English', 'Type', 'Episodes', 'Status', 'Aired',
#        'Premiered', 'Broadcast', 'Producers', 'Licensors', 'Studios', 'Source',
#        'Genres', 'Demographic', 'Duration', 'Rating'],
#       dtype='object')

# %%
data.shape
# Out:
# (1000, 22)

# %% [markdown]
# **2. Summary Statistics and Data Types**

# %%
data.describe()
# Out:
#              Score    Popularity         Rank      Members
# count  1000.000000   1000.000000  1000.000000  1000.000000
# mean      8.156580   1805.637000   500.500000   223.648000
# std       0.284344   1888.308553   288.819436   246.288299
# min       7.800000      1.000000     1.000000     1.000000
# 25%       7.920000    413.750000   250.750000    31.750000
# 50%       8.100000   1139.500000   500.500000   132.000000
# 75%       8.312500   2633.750000   750.250000   330.000000
# max       9.380000  12043.000000  1000.000000   998.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Score        1000 non-null   float64
#  1   Popularity   1000 non-null   int64
#  2   Rank         1000 non-null   int64
#  3   Members      1000 non-null   int64
#  4   Description  1000 non-null   object
#  5   Synonyms     709 non-null    object
#  6   Japanese     999 non-null    object
#  7   English      859 non-null    object
#  8   Type         1000 non-null   object
#  9   Episodes     1000 non-null   object
#  10  Status       1000 non-null   object
#  11  Aired        1000 non-null   object
#  12  Premiered    569 non-null    object
#  13  Broadcast    569 non-null    object
#  14  Producers    1000 non-null   object
#  15  Licensors    1000 non-null   object
#  16  Studios      1000 non-null   object
#  17  Source       1000 non-null   object
# ...

# %%
data.nunique()
# Out:
# Score           121
# Popularity     1000
# Rank           1000
# Members         481
# Description     999
# Synonyms        701
# Japanese        953
# English         856
# Type              6
# Episodes         84
# Status            2
# Aired           961
# Premiered       129
# Broadcast       184
# Producers       641
# Licensors        90
# Studios         166
# Source           15
# Genres          237
# Demographic       5
# Duration        141
# Rating            5
# dtype: int64

# %% [markdown]
# **3. Handle Missing Values**

# %%
data.isnull().any()
# Out:
# Score          False
# Popularity     False
# Rank           False
# Members        False
# Description    False
# Synonyms        True
# Japanese        True
# English         True
# Type           False
# Episodes       False
# Status         False
# Aired          False
# Premiered       True
# Broadcast       True
# Producers      False
# Licensors      False
# Studios        False
# Source         False
# Genres          True
# Demographic     True
# Duration       False
# Rating         False
# dtype: bool

# %%
 #Number of NAN values on each Column
print("Column 'Synonyms'    has     : (",data['Synonyms'].isnull().sum() ,") Null value")
print("Column 'Japanese'    has     : ( "  ,data['Japanese'].isnull().sum() ," ) Null value")
print("Column 'English'     has     : (",data['English'].isnull().sum() ,") Null value")
print("Column 'Premiered'   has     : (",data['Premiered'].isnull().sum() ,") Null value")
print("Column 'Broadcast'   has     : (",data['Broadcast'].isnull().sum() ,") Null value")
print("Column 'Genres'      has     : (",data['Genres'].isnull().sum() ,") Null value")
print("Column 'Demographic' has     : (",data['Demographic'].isnull().sum() ,") Null value")
# Out:
# Column 'Synonyms'    has     : ( 291 ) Null value
# Column 'Japanese'    has     : (  1  ) Null value
# Column 'English'     has     : ( 141 ) Null value
# Column 'Premiered'   has     : ( 431 ) Null value
# Column 'Broadcast'   has     : ( 431 ) Null value
# Column 'Genres'      has     : ( 229 ) Null value
# Column 'Demographic' has     : ( 479 ) Null value

# %%
data.shape
# Out:
# (1000, 22)

# %%
from sklearn.impute import SimpleImputer

# Separate numeric and non-numeric columns
numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns
non_numeric_columns = data.select_dtypes(exclude=['float64', 'int64']).columns

# Impute missing values for numeric columns with mean strategy
numeric_imputer = SimpleImputer(strategy='mean')
data[numeric_columns] = numeric_imputer.fit_transform(data[numeric_columns])

# Impute missing values for non-numeric columns with most frequent strategy
non_numeric_imputer = SimpleImputer(strategy='most_frequent')
data[non_numeric_columns] = non_numeric_imputer.fit_transform(data[non_numeric_columns])

# %% [markdown]
# #### *** We made sure that there is no Null Vlaues ✔️

# %%
# Total number of null values in the data
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# **4. Remove Duplicates:**

# %%
data = data.drop_duplicates()

# %% [markdown]
# **5. Convert Data Types**

# %%
# Convert to appropriate data types
data['Rank'] = data['Rank'].astype(int)
data['Members'] = data['Members'].astype(int)
data['Genres'] = data['Genres'].astype(str)

# Convert date columns to datetime objects
data['Aired'] = pd.to_datetime(data['Aired'], errors='coerce')
data['Premiered'] = pd.to_datetime(data['Premiered'], errors='coerce')

# %% [markdown]
# **6. Feature Engineering**

# %%
data['Aired'] = data['Aired'].replace(np.nan, '1900-01-01')
data['Aired'].dt.year
# Out:
# 0      1900
# 1      1900
# 2      1900
# 3      1900
# 4      1900
#        ...
# 995    2009
# 996    1900
# 997    2005
# 998    2008
# 999    2014
# Name: Aired, Length: 1000, dtype: int64

# %%
data['Premiered']=data['Premiered'].replace(np.nan, '2003-5-9')
data['Premiered'].dt.month
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 995    5
# 996    5
# 997    5
# 998    5
# 999    5
# Name: Premiered, Length: 1000, dtype: int64

# %%
# ADD column for: count the number of genres for each anime:
data['Num_Genres'] = data['Genres'].apply(lambda x: len(x.split(',')))
data['Num_Genres']
# Out:
# 0      3
# 1      4
# 2      3
# 3      3
# 4      3
#       ..
# 995    3
# 996    3
# 997    3
# 998    3
# 999    3
# Name: Num_Genres, Length: 1000, dtype: int64

# %%
# Create a binary column indicating if the anime has more than 50 episodes
# Convert 'Episodes' to numeric
data['Episodes'] = pd.to_numeric(data['Episodes'], errors='coerce')
data['More_Than_50_Episodes'] = data['Episodes'].apply(lambda x: 1 if (pd.notnull(x) and x > 50) else 0)
data['More_Than_50_Episodes']
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: More_Than_50_Episodes, Length: 1000, dtype: int64

# %%
data.shape
# Out:
# (1000, 24)

# %%
# Drop 2 columns we added
data = data.drop(columns=['More_Than_50_Episodes', 'Num_Genres'])

# %% [markdown]
# **7. Normalize/Standardize Data**

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# Select numerical columns
numerical_cols = data.select_dtypes(include=['int64', 'float64']).columns

# Initialize the scalers
scaler_standard = StandardScaler()
scaler_minmax = MinMaxScaler()

# Standardize the data in place
data[numerical_cols] = scaler_standard.fit_transform(data[numerical_cols])

# Normalize the data in place
data[numerical_cols] = scaler_minmax.fit_transform(data[numerical_cols])

# Display the modified DataFrame to verify
print("Standardized and Normalized Data")
print(data.head())
# Out:
# Standardized and Normalized Data
#       Score  Popularity  Rank  Members  \
# 0  1.000000    0.023501     1      710
# 1  0.816456    0.000166     2        3
# 2  0.803797    0.000997     3        2
# 3  0.797468    0.028318     4      630
# 4  0.791139    0.001661     5        2
#
#                                          Description  \
# 0  During their decade-long quest to defeat the D...
# 1  After a horrific alchemy experiment goes wrong...
# 2  Eccentric scientist Rintarou Okabe has a never...
# 3  Gintoki, Shinpachi, and Kagura return as the f...
# 4  Seeking to restore humanity's diminishing hope...
#
#                                             Synonyms  \
# 0                             Frieren at the Funeral
# 1  Hagane no Renkinjutsushi: Fullmetal Alchemist,...
# 2                                           Bokuyaba
# 3                                    Gintama' (2015)
# 4                                           Bokuyaba
#
# ...

# %%
data.describe()
# Out:
#              Score   Popularity         Rank      Members    Episodes
# count  1000.000000  1000.000000  1000.000000  1000.000000  997.000000
# mean      0.225684     0.149862   500.500000   223.648000    0.010563
# std       0.179965     0.156810   288.819436   246.288299    0.036829
# min       0.000000     0.000000     1.000000     1.000000    0.000000
# 25%       0.075949     0.034276   250.750000    31.750000    0.000000
# 50%       0.189873     0.094544   500.500000   132.000000    0.006159
# 75%       0.324367     0.218631   750.250000   330.000000    0.012878
# max       1.000000     1.000000  1000.000000   998.000000    1.000000

# %% [markdown]
# <a id='AnalyzingtheData'></a>

# %% [markdown]
# # 4-Analyzing the Data
#
# ###  Let's embark on our EDA  journey to uncover insights📊

# %%
# Compute correlation matrix
correlation_matrix = data[['Score', 'Popularity', 'Rank', 'Members']].corr()
# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='RdPu', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# %%
palette = sns.color_palette("pastel6")
# Get the counts of each anime type
type_counts = data['Type'].value_counts()
# Plot the pie chart 
plt.figure(figsize=(8, 8))
plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', wedgeprops=dict(width=0.4), colors=palette)
plt.title('Distribution of Anime Types')
plt.axis('equal')
plt.show()

# %%
# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(data['Score'], data['Popularity'], alpha=0.5)
plt.title('Relationship between Score and Popularity')
plt.xlabel('Score')
plt.ylabel('Popularity')
plt.grid(True)
plt.show()

# %%
# Split the 'Genres' column into multiple genres 
data['Genres'] = data['Genres'].str.split(',')
# Create a new DataFrame where each row corresponds to a single genre-score pair
genre_score_data = data.explode('Genres')[['Genres', 'Score']]
# Plotting
plt.figure(figsize=(12, 8))
sns.boxplot(x='Genres', y='Score', data=genre_score_data)
plt.title('Distribution of Scores across Genres')
plt.xlabel('Genres')
plt.ylabel('Score')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=data, x='Type', y='Members')
plt.xlabel('Type of Anime')
plt.ylabel('Members')
plt.title('Distribution of Members for Different Types of Anime (Violin Plot)')
plt.xticks(rotation=45)
plt.show()

# %%
# Assuming 'Aired' and 'Premiered' are datetime columns in DataFrame
# Plotting time series for 'Aired'
plt.figure(figsize=(12, 6))
sns.lineplot(x='Aired', y='Score', data=data, color='blue')
plt.title('Temporal Trends in Score (Aired)')
plt.xlabel('Aired Date')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
# Counting the frequency of each genre
genre_counts = {}
for genre_list in data['Genres']:
    for genre in genre_list:
        genre_counts[genre] = genre_counts.get(genre, 0) + 1

# Sorting genres by frequency
sorted_genres = sorted(genre_counts.items(), key=lambda x: x[1], reverse=True)

# Creating a bar plot to visualize the frequency of each genre
plt.figure(figsize=(12, 6))
sns.barplot(x=[genre[1] for genre in sorted_genres], y=[genre[0] for genre in sorted_genres], palette='viridis')
plt.xlabel('Frequency')
plt.ylabel('Genres')
plt.title('Distribution of Anime Across Different Genres')
plt.show()

# %%
# Create a box plot or violin plot to compare Scores or Popularity among different demographics
plt.figure(figsize=(12, 8))
sns.boxplot(x='Demographic', y='Score', data=data, palette='Set2')
plt.xlabel('Demographic')
plt.ylabel('Score')
plt.title('Distribution of Scores Across Different Demographics')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Plot the distribution of content ratings
plt.figure(figsize=(15, 3))
sns.countplot(data=data, x='Rating', palette='Set2')
plt.xlabel('Content Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Content Ratings')
plt.show()

# Analyze patterns in Scores based on ratings using box plots
plt.figure(figsize=(15, 3))
sns.boxplot(data=data, x='Rating', y='Score', palette='Set2')
plt.xlabel('Content Rating')
plt.ylabel('Score')
plt.title('Trends in Scores based on Ratings')
plt.show()

# Analyze trends in Popularity based on ratings using box plots
plt.figure(figsize=(15, 3))
sns.boxplot(data=data, x='Rating', y='Popularity', palette='Set2')
plt.xlabel('Content Rating')
plt.ylabel('Popularity')
plt.title('Trends in Popularity based on Ratings')
plt.show()

# %% [markdown]
# <a id='DataVisualization'>

# %% [markdown]
# # Asking and Answering Questions🎯

# %% [markdown]
# ##  1. What is the general distribution of scores among the top animes in the dataset?

# %%
# Filter the dataset to consider only the top animes 
top_animes = data[data['Rank'] <= 100]
# Create a histogram plot of the scores
plt.figure(figsize=(10,3))
sns.histplot(top_animes['Score'], kde=True, color='darkorchid', bins=20)
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.title('Distribution of Scores Among Top Animes')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## 2. How is the popularity of animes distributed, and what are the most popular titles?

# %%
# Create a histogram of the popularity
plt.figure(figsize=(10, 3))
sns.histplot(data['Popularity'], kde=False, color='hotpink', bins=20)
plt.xlabel('Popularity')
plt.ylabel('Frequency')
plt.title('Distribution of Anime Popularity')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
data['Genres'] = data['Genres'].astype(str)
# Sort the dataset by popularity
top_popular_animes = data.sort_values(by='Popularity', ascending=False).head(10)

# Display the top popular titles
print("Top 10 Most Popular Animes:")
print(top_popular_animes[['English', 'Popularity']])
# Out:
# Top 10 Most Popular Animes:
#                                             English  Popularity
# 751                       Fog Hill of Five Elements    1.000000
# 669  Genshin Impact: The Song Burning in the Embers    0.966368
# 244                       Swallowed Star 3rd Season    0.950174
# 518                                The Demon Hunter    0.941372
# 351                       Swallowed Star 4th Season    0.934147
# 363                       Fog Hill of Five Elements    0.854841
# 639             Soul Land 2: The Peerless Tang Clan    0.828683
# 979                       Fog Hill of Five Elements    0.816808
# 579                       Throne of Seal 2nd Season    0.780850
# 773                       Fog Hill of Five Elements    0.743398

# %% [markdown]
# ## 3. What are the top 10 animes with the highest average ratings?

# %%
top_10_average_ratings = data.groupby('English')['Score'].mean().sort_values(ascending=False).head(10)
#print(top_10_average_ratings)
plt.figure(figsize=(8, 8))
colors = ['pink','purple','hotpink','violet','lightpink','plum','deeppink','indigo','lightyellow','darkorchid']
explode=(0,0.2,0,0,0.2,0,0,0,0.1,0)   #to make a distance in selected bar
plt.pie(top_10_average_ratings,colors=colors,explode=explode,wedgeprops={'edgecolor':'black'},labels=top_10_average_ratings.index, autopct='%1.1f%%', startangle=50)
plt.title('Top 10 Average Ratings by Anime Title')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ## 4. Which genres are most prevalent in the dataset, and which studios produce the most animes?

# %%
# Most prevalent genres
top_genres = data['Genres'].str.split(',').explode().str.strip().value_counts().head(10)
print("Top 10 Most Prevalent Genres:")
print(top_genres)
# Studios producing the most animes
top_studios = data['Studios'].str.split(',').explode().str.strip().value_counts().head(10)
print("\nTop 10 Studios Producing the Most Animes:")
print(top_studios)
# Out:
# Top 10 Most Prevalent Genres:
# ['ActionAction'                 595
# ' FantasyFantasy']              376
# ' AdventureAdventure'           354
# ' DramaDrama'                   156
# ' Sci-FiSci-Fi']                143
# ' SupernaturalSupernatural']    126
# ' ComedyComedy'                 112
# ['ComedyComedy'                 111
# ' RomanceRomance']              103
# ' FantasyFantasy'               101
# Name: Genres, dtype: int64
#
# Top 10 Studios Producing the Most Animes:
# Madhouse             61
# Production I.G       60
# Sunrise              52
# TMS Entertainment    50
# Bones                41
# Toei Animation       40
# A-1 Pictures         36
# Kyoto Animation      36
# J.C.Staff            33
# Shaft                31
# Name: Studios, dtype: int64

# %% [markdown]
# ## 5. How does the number of episodes affect the average rating of an anime?

# %%
# Group the data by the number of episodes and calculate the average rating
average_rating_by_episodes = data.groupby('Episodes')['Score'].mean()
# Plot the relationship
plt.figure(figsize=(10, 3))
plt.plot(average_rating_by_episodes.index, average_rating_by_episodes.values, marker='o', linestyle='-')
plt.xlabel('Number of Episodes')
plt.ylabel('Average Rating')
plt.title('Average Rating by Number of Episodes')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Made with 💖 by : Menna Khaled
